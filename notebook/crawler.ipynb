# %%
#-*- coding: utf-8 -*-
from bs4 import BeautifulSoup
import selenium
from selenium import webdriver
from konlpy.utils import pprint
import datetime
import time
import csv
import sys
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pylab as plt
import matplotlib.dates as mdates
import seaborn as sns
import dateutil
import random

# %%
import hashlib

# %%
hashlib.sha1('최영록').ipynb_checkpoints/
# Out:
# <sha1 HASH object @ 0x116ddbf08>

# %%
# time stamp to check the running time
start_time = time.time()

# URL to get info
url = "http://www.coupang.com/vp/products/2801591?itemId=14692254&vendorItemId=3002041112&q=%ED%94%BC%EC%A7%80%EC%98%A4%EA%B2%94&itemsCount=36&searchId=a4f42676db164355abac4e6735dbc962&vendorItemId=3002041112&rank=1"

# build webdriver instance
driver = webdriver.Firefox(executable_path='/usr/local/bin/geckodriver')
driver.get(url)

# open the review tab
driver.execute_script("window.scrollBy(0, 1500);")
time.sleep(5)
element = driver.find_element_by_class_name("product-tab-title-list-wraper").find_elements_by_class_name("product-tab-title__list")[1]
element.click()

# 'lates' tab
time.sleep(5)
driver.find_elements_by_class_name('js_reviewArticleSortBtn')[1].click()
element.click()

# build bs4
soup = BeautifulSoup(driver.page_source, 'lxml')

# get the total number
item_len = int(soup.find(class_="sdp-review__average__total-star__info-count").getText().replace(',', ''))
get_len = 0
print("total: {}".format(item_len))
print("get: {}".format(get_len))

# file path
PATH = '../dataset/sample.csv'

# initialize columns header
f = open(PATH, 'w')
wr = csv.writer(f)
wr.writerow(['uid', 'user_name', 'rating', 'date', 'text', 'option_name', 'help_count', 'perfume', 'moisture'])
f.close()   
        
while(item_len != get_len):
# paging
    page_len = len(driver.find_elements_by_class_name('js_reviewArticlePageBtn'))
    print('pages: {}'.format(page_len))
    
    for i in range(page_len):
        temp = driver.find_elements_by_class_name('js_reviewArticlePageBtn')
        temp[i].click()
        white_noise = random.random() / 5.0
        time.sleep(2.8 + white_noise)
        
        # build bs4
        soup = BeautifulSoup(driver.page_source, 'lxml')

        # get the review list
        items = soup.find(class_="js_reviewArticleListContainer").find_all("article")
        get_len += len(items)
        print("get: {}".format(get_len))

        for i in range(len(items)):
            # attributes
            uid = None
            user_name = None
            rating = None
            date = None
            text = None
            option_name = None
            help_count = None
            perfume = None
            moisture = None
            
            # uid
            try:
                uid = items[i].find(class_="js_reviewArticleHelpfulContainer").get('data-review-id').encode('utf-8')
            except:
                pass
            
            # user name
            try:
                user_name = items[i].find(class_="sdp-review__article__list__info__user__name js_reviewUserProfileImage").getText().encode('utf-8')
            except:
                pass

            # rating
            try:
                rating = int(items[i].find(class_="js_reviewArticleRatingValue").find(class_="hide_txt").get('data-rating'))
            except:
                pass

            # date
            try:
                date = items[i].find(class_="sdp-review__article__list__info__product-info__reg-date").getText().encode('utf-8')
            except:
                pass

            # text
            try:
                text = items[i].find(class_="js_reviewArticleContent").getText().encode('utf-8')
            except:
                pass

            # option_name
            try:
                option_name = items[i].find(class_="sdp-review__article__list__info__product-info__name").getText().encode('utf-8')
            except:
                pass

            # help_count
            try:
                help_count = int(items[i].find(class_="js_reviewArticleHelpfulContainer").get('data-count'))
            except:
                pass

            # perfume
            try:
                perfume = items[i].find("span", string=u"향 만족도").parent.find_all("span")[1].getText().encode('utf-8')
            except:
                pass

            # moisture
            try:
                moisture = items[i].find("span", string=u"보습력").parent.find_all("span")[1].getText().encode('utf-8')
            except:
                pass

            print("=={}".format((get_len - 5) + i) + "==") 
            print(uid)
            print(user_name)
            print(date)
            print(rating)
            print(text)
            print(option_name)
            print("help_count: {}".format(help_count))
            print(perfume)
            print(moisture)
            print(" ")

            # write a record
            f = open(PATH, 'a')
            wr = csv.writer(f)
            wr.writerow([uid, user_name, rating, date, text, option_name, help_count, perfume, moisture])
            f.close()
    
    # move to next 10 pages
    try:
        driver.find_element_by_class_name('js_reviewArticlePageNextBtn').click()
        white_noise = random.random() / 5.0
        time.sleep(2.8 + white_noise)
    except:
        pass
   
print(" ")

end_time = time.time()
running_time = end_time - start_time
print("Total running time: {} minutes").format(running_time / 60)
# Out:
# total: 7064
# get: 0
# pages: 10
# get: 5
# ==0==
# 28989543
# 전*율
# 2017.08.11
# None
# None
# 피지오겔  데일리 모이스쳐 테라피 페이셜 크림, 150ml
# help_count: 0
# None
# None
#
# ==1==
# 28984474
# 허*미
# 2017.08.11
# None
# None
# 피지오겔  데일리 모이스쳐 테라피 페이셜 크림, 150ml
# help_count: 0
# None
# None
#
# ==2==
# 28973581
# 정*화
# 2017.08.11
# None
#
#
#                         늘 사용하는제품이예요 ^^-
# 촉촉해지는 그날까징~~~~ㅋ
#
#
# 피지오겔  데일리 모이스쳐 테라피 페이셜 크림, 150ml
# help_count: 0
# 적당히 만족해요
# 예상만큼 좋아요
#
# ==3==
# 28972303
# 최*영
# 2017.08.11
# None
#
#
#                         아기피부가 건조해서 이것저것 다 써봤는데 피지오겔은 비싸서 안사려다가 만구천원대로 내려간거보고 한번사봤어요 바를때 질감이 부드러워서 혹시나 하고 피부가 좋아지진 않나 기대했는데 그냥 그렇네요 ㅎ ㅎ 바른지 일주일정도 되었는데 며칠 더 발라봐야 하는건지 ㅎ ㅎ 다른 크림들하고 차이를 잘모르겠어요 ㅎ ㅎ
#
#
# 피지오겔  데일리 모이스쳐 테라피 페이셜 크림, 150ml
# help_count: 0
# None
# None
#
# ==4==
# 28970886
# 김*영
# 2017.08.11
# None
#
#
#                         배송도 빠르고 아주 좋은 상품을 구입하고 갑니다.
#
#
# 이거 진짜 순하고 좋습니다.
#
#
# 피지오겔  데일리 모이스쳐 테라피 페이셜 크림, 150ml
# help_count: 0
# 아주 만족해요
# 예상만큼 좋아요
#
# get: 10
# ==5==
# 28966088
# 이*숙
# 2017.08.11
# None
#
#
#                         계속써오던 상품이라  보습력좋고 스킨 하나바르고  바로 피지오겔발라주면 며름기초화장 끝
# 너무 편하고 좋습니다
#
#
# 피지오겔  데일리 모이스쳐 테라피 페이셜 크림, 150ml
# help_count: 0
# 아주 만족해요
# 예상만큼 좋아요
#
# ==6==
# 28952758
# 이*진
# 2017.08.11
# None
# None
# 피지오겔 데일리 모이스쳐 테라피 페이셜 크림, 150ml, 2개
# help_count: 0
# None
# None
#
# ==7==
# 28949991
# 김*연
# 2017.08.10
# None
# None
# 피지오겔  데일리 모이스쳐 테라피 페이셜 크림, 150ml, 2개
# help_count: 0
# None
# None
#
# ==8==
# 28943261
# 강*석
# 2017.08.10
# None
#
#
#                         박스 봉인이 뜯어져있네요. . 이건 그렇다쳐도 마개에  원래 은박지로 붙어있지않나요? 이건없네요. .  찝찝해요
#
#
# 피지오겔  데일리 모이스쳐 테라피 페이셜 크림, 150ml
# help_count: 0
# None
# None
#
# ==9==
# 28932585
# 이*은
# 2017.08.10
# None
# None
# 피지오겔 데일리 모이스쳐 테라피 페이셜 크림, 150ml
# help_count: 0
# 아주 만족해요
# 예상만큼 좋아요
#
# get: 15
# ==10==
# 28931386
# 임*은
# 2017.08.10
# None
#
#
#                         좋아요좋아요
#
#
# 피지오겔 데일리 모이스쳐 테라피 페이셜 크림, 150ml
# help_count: 0
# None
# None
#
# ==11==
# 28931324
# 임*은
# 2017.08.10
# None
#
#
#                         늘 사용하는제품입니다 배송도 빠르구요
#
#
# 피지오겔 데일리 모이스쳐 테라피 페이셜 크림, 150ml
# help_count: 0
# 아주 만족해요
# 예상만큼 좋아요
#
# ==12==
# 28929498
# L*O
# 2017.08.10
# None
# None
# 피지오겔 데일리 모이스쳐 테라피 페이셜 크림, 150ml
# help_count: 0
# None
# None
#
# ==13==
# 28919773
# 조*진
# 2017.08.10
# None
# None
# 피지오겔  데일리 모이스쳐 테라피 페이셜 크림, 150ml
# help_count: 0
# None
# None
#
# ==14==
# 28914159
# 노*규
# 2017.08.10
# None
# None
# 피지오겔 데일리 모이스쳐 테라피 페이셜 크림 , 150ml
# help_count: 0
# None
# None
#
# get: 20
# ==15==
# 28903758
# 신*유
# 2017.08.10
# None
# None
# 피지오겔  데일리 모이스쳐 테라피 페이셜 크림, 150ml
# help_count: 0
# None
# None
#
# ==16==
# 28897450
# 이*욱
# 2017.08.10
# None
#
#
#                         역시 굿
#
#
# 피지오겔 데일리 모이스쳐 테라피 페이셜 크림, 150ml
# help_count: 0
# 아주 만족해요
# 예상만큼 좋아요
#
# ==17==
# 28889056
# 최*희
# 2017.08.10
# None
# None
# 피지오겔 데일리 모이스쳐 테라피 페이셜 크림, 150ml, 2개
# help_count: 0
# None
# None
#
# ==18==
# 28878242
# 김*숙
# 2017.08.09
# None
# None
# 피지오겔  데일리 모이스쳐 테라피 페이셜 크림, 150ml
# help_count: 0
# 아주 만족해요
# 예상만큼 좋아요
#
# ==19==
# 28868097
# 김*경
# 2017.08.09
# None
#
#
#                         순해요
# 피부가 좋아지던가 그런느낌은 없고
# 그냥 순한느낌이에요
# 촉촉하고! 지성은 안쓰시는게 좋을것같아요
#
#
# 피지오겔 데일리 모이스쳐 테라피 페이셜 크림, 150ml
# help_count: 0
# 적당히 만족해요
# 중간 정도에요
#
# get: 25
# ==20==
# 28865160
# 김*희
# 2017.08.09
# None
#
#
#                         배송 좋고 상품 좋고
#
#
# 피지오겔 데일리 모이스쳐 테라피 페이셜 크림, 150ml
# help_count: 0
# None
# None
#
# ==21==
# 28849713
# 박*민
# 2017.08.09
# None
#
#
#                         피지오겔은 늘 좋음 싸게잘삼
#
#
# 피지오겔 데일리 모이스쳐 테라피 페이셜 크림, 150ml
# help_count: 0
# None
# None
#
# ==22==
# 28847038
# 이*형
# 2017.08.09
# None
# None
# 피지오겔  데일리 모이스쳐 테라피 페이셜 크림, 150ml
# help_count: 0
# 적당히 만족해요
# None
#
# ==23==
# 28841158
# 하*실
# 2017.08.09
# None
#
#
#                         싸고 좋아요! 제조일도 그렇게 오래 되지 않았어요
#
#
# 피지오겔  데일리 모이스쳐 테라피 페이셜 크림, 150ml
# help_count: 0
# 아주 만족해요
# 예상만큼 좋아요
#
# ==24==
# 28835853
# 송*은
# 2017.08.09
# None
# None
# 피지오겔  데일리 모이스쳐 테라피 페이셜 크림, 150ml
# help_count: 0
# None
# None
#
# get: 30
# ==25==
# 28829229
# 전*희
# 2017.08.09
# None
#
#
#                         피부가 뒤집어져서 좋다길래 사서 쓰고있는중이에요
# 아직 뭐 효과는 잘 모르겠지만
# 건조했던 피부에는 좋을것 같은 느낌이네요
# 트러블은.. 아직 지켜봐야겠어요!
#
#
# 피지오겔  데일리 모이스쳐 테라피 페이셜 크림, 150ml
# help_count: 0
# 적당히 만족해요
# 중간 정도에요
#
# ==26==
# 28821975
# 김*수
# 2017.08.09
# None
#
#
#                         ㄱㅊ
#
#
# 피지오겔 데일리 모이스쳐 테라피 페이셜 크림, 150ml
# help_count: 0
# None
# None
#
# ==27==
# 28813029
# 김*애
# 2017.08.08
# None
#
#
#                         피지오겔 쓰고 피부 많이 좋아졌습니다 겨울 여름 4계절 이거만 씁니다
#
#
# 피지오겔 데일리 모이스쳐 테라피 페이셜 크림, 150ml
# help_count: 0
# None
# None
#
# ==28==
# 28806559
# 윤*물
# 2017.08.08
# None
#
#
#                         역시피지오겔
# 성분 순해서 피부에 부담없고
# 쿠팡으로 사니까 가격도 부담없어서 좋았어요
# 배송 빠른게 가장 좋네요 쿠팡맨
#
#
# 피지오겔  데일리 모이스쳐 테라피 페이셜 크림, 150ml
# help_count: 0
# 아주 만족해요
# 예상만큼 좋아요
#
# ==29==
# 28789025
# 은댕이
# 2017.08.08
# None
# None
# 피지오겔 데일리 모이스쳐 테라피 페이셜 크림, 150ml
# help_count: 0
# 만족스럽지 않아요
# 예상만큼 좋아요
#
# get: 35
# ==30==
# 28780455
# 최*영
# 2017.08.08
# None
# None
# 피지오겔 데일리 모이스쳐 테라피 페이셜 크림, 150ml
# help_count: 0
# 아주 만족해요
# 예상만큼 좋아요
#
# ==31==
# 28771020
# 신*휘
# 2017.08.08
# None
#
#
#                         몇년째 계속 사용중! 짱!!!
#
#
# 피지오겔 데일리 모이스쳐 테라피 페이셜 크림, 150ml
# help_count: 0
# None
# None
#
# ==32==
# 28769728
# 이*혜
# 2017.08.08
# None
# None
# 피지오겔  데일리 모이스쳐 테라피 페이셜 크림, 150ml
# help_count: 0
# 아주 만족해요
# None
#
# ==33==
# 28765237
# 서*심
# 2017.08.08
# None
# None
# 피지오겔 데일리 모이스쳐 테라피 페이셜 크림, 150ml
# help_count: 0
# 아주 만족해요
# 예상만큼 좋아요
#
# ==34==
# 28757195
# 김*희
# 2017.08.08
# None
#
#
#                         꾸준히쓰는제품입니다 발림성좋고
# 저자극성이라 믿고쓰죠ㅎ향은그닥좋지않읏데
# 잘쓰고있습니다ㅎ
#
#
# 피지오겔 데일리 모이스쳐 테라피 페이셜 크림, 150ml
# help_count: 0
# 아주 만족해요
# 중간 정도에요
#
# get: 40
# ==35==
# 28730349
# 김*희
# 2017.08.07
# None
# None
# 피지오겔 데일리 모이스쳐 테라피 페이셜 크림, 150ml
# help_count: 0
# None
# None
#
# ==36==
# 28722427
# 신*윤
# 2017.08.07
# None
#
#
#                         몇번이나 구매햤는데 좋아요
#
#
# 피지오겔 데일리 모이스쳐 테라피 페이셜 크림, 150ml
# help_count: 0
# None
# None
#
# ==37==
# 28713958
# 현*윤
# 2017.08.07
# None
#
#
#                         좋아요
#
#
# 피지오겔  데일리 모이스쳐 테라피 페이셜 크림, 150ml
# help_count: 0
# None
# None
#
# ==38==
# 28707162
# 임*화
# 2017.08.07
# None
#
#
#                         배송 빠르고 예민한 아이피부와 제피부에 딱좋아요~
#
#
# 피지오겔 데일리 모이스쳐 테라피 페이셜 크림, 150ml
# help_count: 0
# None
# None
#
# ==39==
# 28683525
# 조*희
# 2017.08.06
# None
# None
# 피지오겔  데일리 모이스쳐 테라피 페이셜 크림, 150ml
# help_count: 0
# 아주 만족해요
# None
#
# get: 45
# ==40==
# 28667365
# 김*한
# 2017.08.06
# None
# None
# 피지오겔 데일리 모이스쳐 테라피 페이셜 크림, 150ml
# help_count: 0
# None
# None
#
# ==41==
# 28666819
# 김*정
# 2017.08.06
# None
# None
# 피지오겔 데일리 모이스쳐 테라피 페이셜 크림, 150ml
# help_count: 0
# 아주 만족해요
# 예상만큼 좋아요
#
# ==42==
# 28666670
# 심*진
# 2017.08.06
# None
# None
# 피지오겔  데일리 모이스쳐 테라피 페이셜 크림, 150ml
# help_count: 0
# None
# None
#
# ==43==
# 28663327
# 황*혜
# 2017.08.06
# None
# None
# 피지오겔 데일리 모이스쳐 테라피 페이셜 크림, 150ml
# help_count: 0
# None
# None
#
# ==44==
# 28651888
# 최*혜
# 2017.08.06
# None
# None
# 피지오겔 데일리 모이스쳐 테라피 페이셜 크림, 150ml
# help_count: 0
# None
# None
#
# get: 50
# ==45==
# 28640351
# 채*진
# 2017.08.06
# None
# None
# [피지오겔] DMT 크림  150ml
# help_count: 0
# None
# None
#
# ==46==
# 28632479
# P*G
# 2017.08.05
# None
# None
# 피지오겔 데일리 모이스쳐 테라피 페이셜 크림 , 150ml
# help_count: 0
# None
# None
#
# ==47==
# 28618460
# 정*지
# 2017.08.05
# None
#
#
#                         매번 사용하는 제품인데 저렴하게 잘 삿습니당
#
#
# 피지오겔 데일리 모이스쳐 테라피 페이셜 크림, 150ml
# help_count: 0
# 아주 만족해요
# 예상만큼 좋아요
#
# ==48==
# 28608506
# 강*진
# 2017.08.05
# None
#
#
#                         몇 년째 쓰는 제품이예요~
# 다른 기초화장품 없이 피지오겔크링과 선크림으로
# 피부가 좋아졌 어요~~ 여름이면 항상 얼굴이  따끔거렸는데
# 그것도 다 없어지고~  암튼 전 화장품은 이거 하나만발라요~
# 자극도 없고 완전 좋은 제품입니다~~
#
#
# 피지오겔 데일리 모이스쳐 테라피 페이셜 크림, 150ml
# help_count: 0
# 아주 만족해요
# 예상만큼 좋아요
#
# ==49==
# 28606411
# 이*영
# 2017.08.05
# None
# None
# 피지오겔 데일리 모이스쳐 테라피 페이셜 크림, 150ml
# help_count: 0
# None
# None
#
# pages: 10
# get: 55
# ==50==
# 28602762
# 조*성
# 2017.08.05
# None
# None
# 피지오겔 데일리 모이스쳐 테라피 페이셜 크림, 150ml
# help_count: 0
# None
# None
#
# ==51==
# 28593138
# 신*욱
# 2017.08.05
# None
# None
# 피지오겔 데일리 모이스쳐 테라피 페이셜 크림, 150ml
# help_count: 0
# 아주 만족해요
# None
#
# ==52==
# 28584972
# 정*훈
# 2017.08.05
# None
#
#
#                         조금 기름진느낌이 없지않아있어요
#
#
# 피지오겔 데일리 모이스쳐 테라피 페이셜 크림, 150ml
# help_count: 0
# None
# None
#
# ==53==
# 28584914
# 조*라
# 2017.08.05
# None
#
#
#                         가격부담이 되도 계속 쓰고 있는 피지오겔 크림
# 귀찮을때 이거 하나만 바르고 자도 다음날 화장 잘먹고 얼굴에서 광나요
# 전 밤엔 듬뿍 아침엔 적당량만 발라요(집순이일땐 듬뿍)
# 건성 민감성 피부에 좋아요 무향에 자극없고 보습력 좋아요
# 로켓배송 덕분에 빠르게 쓸 수 있어서 좋았어요
#
#
# 피지오겔 데일리 모이스쳐 테라피 페이셜 크림, 150ml
# help_count: 0
# 아주 만족해요
# 예상만큼 좋아요
#
# ==54==
# 28581673
# 안*영
# 2017.08.04
# None
#
#
#                         촉촉해서 수분크림대신바르는데 좋아요
#
#
# 피지오겔 데일리 모이스쳐 테라피 페이셜 크림, 150ml
# help_count: 0
# None
# None
#
# get: 60
# ==55==
# 28567308
# 윤*나
# 2017.08.04
# None
#
#
#                         배송빨라 좋네요
#
#
# 피지오겔 데일리 모이스쳐 테라피 페이셜 크림, 150ml
# help_count: 0
# 아주 만족해요
# 예상만큼 좋아요
#
# ==56==
# 28566764
# 방*경
# 2017.08.04
# None
# None
# 피지오겔 데일리 모이스쳐 테라피 페이셜 크림, 150ml
# help_count: 0
# None
# None
#
# ==57==
# 28558781
# 남*진
# 2017.08.04
# None
# None
# 피지오겔 데일리 모이스쳐 테라피 페이셜 크림, 150ml
# help_count: 0
# 아주 만족해요
# 예상만큼 좋아요
#
# ==58==
# 28558375
# 이*
# 2017.08.04
# None
# None
# 피지오겔 데일리 모이스쳐 테라피 페이셜 크림, 150ml
# help_count: 0
# None
# None
#
# ==59==
# 28558261
# 이*
# 2017.08.04
# None
# None
# 피지오겔 데일리 모이스쳐 테라피 페이셜 크림, 150ml
# help_count: 0
# None
# None
#
# get: 65
# ==60==
# 28555289
# 김*희
# 2017.08.04
# None
# None
# [피지오겔] DMT 크림  150ml
# help_count: 0
# None
# None
#
# ==61==
# 28555217
# 김*희
# 2017.08.04
# None
# None
# [피지오겔] DMT 크림  150ml
# help_count: 0
# None
# None
#
# ==62==
# 28542147
# 김*희
# 2017.08.04
# None
#
#
#                         1. 배송 : 로켓 아니어도 괜찬은데, 다음날 바로 도착헸네요. 배송기사님 감사합니다.
# 2. 제품 : 피지오겔 크림 똑같은 것으로 또 주문해서 사용합니다. 저는 민감피부라 무향을 선호해서 무향이라 좋고, 사계절 내내 사용하기 무리없구요. 여름엔 생각보단 덜 번들거리고, 겨울엔 저녁에 바르면 아침까지 건조함이 없어 좋습니다. 주문하면서 사용기한 내심 걱정했는데, 이번에도 안심이네요. (제가 사용하는 기간까지 넉넉해요-유통기한이 내년5월?6월까지인것 같았어요. 제품받고 며칠지난터라 정확한 기억이 안남.)
#
#
# 피지오겔 데일리 모이스쳐 테라피 페이셜 크림, 150ml
# help_count: 0
# 아주 만족해요
# 예상만큼 좋아요
#
# ==63==
# 28536984
# 곽*주
# 2017.08.04
# None
# None
# 피지오겔 데일리 모이스쳐 테라피 페이셜 크림, 150ml
# help_count: 0
# 적당히 만족해요
# 중간 정도에요
#
# ==64==
# 28526299
# 채*선
# 2017.08.04
# None
# None
# 피지오겔 데일리 모이스쳐 테라피 페이셜 크림, 150ml, 2개
# help_count: 0
# None
# None
#
# get: 70
# ==65==
# 28517139
# 박*미
# 2017.08.03
# None
# None
# 피지오겔 데일리 모이스쳐 테라피 페이셜 크림, 150ml
# help_count: 0
# None
# None
#
# ==66==
# 28505183
# 곽*신
# 2017.08.03
# None
# None
# 피지오겔 데일리 모이스쳐 테라피 페이셜 크림 , 150ml
# help_count: 0
# None
# None
#
# ==67==
# 28492303
# 유*형
# 2017.08.03
# None
# None
# 피지오겔 데일리모이스쳐 테라피 페이셜 크림, 150ml
# help_count: 0
# None
# None
#
# ==68==
# 28484860
# 윤*현
# 2017.08.03
# None
# None
# 피지오겔 데일리 모이스쳐 테라피 페이셜 크림, 150ml
# help_count: 0
# 아주 만족해요
# 예상만큼 좋아요
#
# ==69==
# 28482576
# 이*태
# 2017.08.03
# None
# None
# 피지오겔 데일리 모이스쳐 테라피 페이셜 크림, 150ml
# help_count: 0
# None
# None
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-679775c44e91> in <module>()
#      50
#      51         # build bs4
# ---> 52         soup = BeautifulSoup(driver.page_source, 'lxml')
#      53
#      54         # get the review list
#
# /Users/choiyoungrok/anaconda/lib/python2.7/site-packages/bs4/__init__.pyc in __init__(self, markup, features, builder, parse_only, from_encoding, exclude_encodings, **kwargs)
#     226             self.reset()
#     227             try:
# --> 228                 self._feed()
#     229                 break
#     230             except ParserRejectedMarkup:
#
# /Users/choiyoungrok/anaconda/lib/python2.7/site-packages/bs4/__init__.pyc in _feed(self)
#     287         self.builder.reset()
#     288
# --> 289         self.builder.feed(self.markup)
#     290         # Close out any unfinished strings and close all the open tags.
#     291         self.endData()
#
# /Users/choiyoungrok/anaconda/lib/python2.7/site-packages/bs4/builder/_lxml.pyc in feed(self, markup)
#     248         try:
#     249             self.parser = self.parser_for(encoding)
# --> 250             self.parser.feed(markup)
#     251             self.parser.close()
#     252         except (UnicodeDecodeError, LookupError, etree.ParserError), e:
#
# src/lxml/parser.pxi in lxml.etree._FeedParser.feed (src/lxml/lxml.etree.c:113776)()
#
# src/lxml/parser.pxi in lxml.etree._FeedParser.feed (src/lxml/lxml.etree.c:113649)()
#
# src/lxml/parsertarget.pxi in lxml.etree._TargetParserContext._handleParseResult (src/lxml/lxml.etree.c:130442)()
#
# src/lxml/parsertarget.pxi in lxml.etree._TargetParserContext._handleParseResult (src/lxml/lxml.etree.c:130238)()
#
# src/lxml/lxml.etree.pyx in lxml.etree._ExceptionContext._raise_if_stored (src/lxml/lxml.etree.c:12081)()
#
# src/lxml/saxparser.pxi in lxml.etree._handleSaxTargetStartNoNs (src/lxml/lxml.etree.c:122716)()
#
# src/lxml/saxparser.pxi in lxml.etree._callTargetSaxStart (src/lxml/lxml.etree.c:122913)()
#
# src/lxml/parsertarget.pxi in lxml.etree._PythonSaxParserTarget._handleSaxStart (src/lxml/lxml.etree.c:129235)()
#
# /Users/choiyoungrok/anaconda/lib/python2.7/site-packages/bs4/builder/_lxml.pyc in start(self, name, attrs, nsmap)
#     181         namespace, name = self._getNsTag(name)
#     182         nsprefix = self._prefix_for_namespace(namespace)
# --> 183         self.soup.handle_starttag(name, namespace, nsprefix, attrs)
#     184
#     185     def _prefix_for_namespace(self, namespace):
#
# /Users/choiyoungrok/anaconda/lib/python2.7/site-packages/bs4/__init__.pyc in handle_starttag(self, name, namespace, nsprefix, attrs)
#     463
#     464         tag = Tag(self, self.builder, name, namespace, nsprefix, attrs,
# --> 465                   self.currentTag, self._most_recent_element)
#     466         if tag is None:
#     467             return tag
#
# /Users/choiyoungrok/anaconda/lib/python2.7/site-packages/bs4/element.pyc in __init__(self, parser, builder, name, namespace, prefix, attrs, parent, previous, is_xml)
#     847         self.attrs = attrs
#     848         self.contents = []
# --> 849         self.setup(parent, previous)
#     850         self.hidden = False
#     851
#
# /Users/choiyoungrok/anaconda/lib/python2.7/site-packages/bs4/element.pyc in setup(self, parent, previous_element, next_element, previous_sibling, next_sibling)
#     209         self.previous_element = previous_element
#     210         if previous_element is not None:
# --> 211             self.previous_element.next_element = self
#     212
#     213         self.next_element = next_element
#
# KeyboardInterrupt:

# %%
driver.find_element_by_class_name("product-tab-title-list-wraper").find_elements_by_class_name("product-tab-title__list")[1].click()

# %%
df = pd.read_csv(PATH)
df
# Out:
#            uid user_name  rating        date  \
# 0     28683525      조*희      NaN  2017.08.06
# 1     28667365      김*한      NaN  2017.08.06
# 2     28666819      김*정      NaN  2017.08.06
# 3     28666670      심*진      NaN  2017.08.06
# 4     28663327      황*혜      NaN  2017.08.06
# 5     28651888      최*혜      NaN  2017.08.06
# 6     28640351      채*진      NaN  2017.08.06
# 7     28632479      P*G      NaN  2017.08.05
# 8     28618460      정*지      NaN  2017.08.05
# 9     28608506      강*진      NaN  2017.08.05
# 10    28606411      이*영      NaN  2017.08.05
# 11    28602762      조*성      NaN  2017.08.05
# 12    28593138      신*욱      NaN  2017.08.05
# 13    28584972      정*훈      NaN  2017.08.05
# 14    28584914      조*라      NaN  2017.08.05
# 15    28581673      안*영      NaN  2017.08.04
# 16    28567308      윤*나      NaN  2017.08.04
# 17    28566764      방*경      NaN  2017.08.04
# 18    28558781      남*진      NaN  2017.08.04
# 19    28558375       이*      NaN  2017.08.04
# 20    28558261       이*      NaN  2017.08.04
# 21    28555289      김*희      NaN  2017.08.04
# 22    28555217      김*희      NaN  2017.08.04
# 23    28542147      김*희      NaN  2017.08.04
# 24    28536984      곽*주      NaN  2017.08.04
# 25    28526299      채*선      NaN  2017.08.04
# 26    28517139      박*미      NaN  2017.08.03
# 27    28505183      곽*신      NaN  2017.08.03
# 28    28492303      유*형      NaN  2017.08.03
# 29    28484860      윤*현      NaN  2017.08.03
# ...        ...       ...     ...         ...
# 6995   1057747      이*미      NaN  2015.11.24
# 6996   1055044      박*석      NaN  2015.11.24
# 6997   1036945      배*채      NaN  2015.11.20
# 6998   1034835      원*빈      NaN  2015.11.20
# 6999   1031622      김*정      NaN  2015.11.19
# 7000   1030423      김*희      NaN  2015.11.19
# 7001   1026544      장*현      NaN  2015.11.18
# 7002   1025879      채*은      NaN  2015.11.18
# 7003   1023053      김*선      NaN  2015.11.18
# 7004    999123      한*숙      NaN  2015.11.14
# 7005    999036      최*아      NaN  2015.11.14
# 7006    998151      전*주      NaN  2015.11.13
# 7007    990590      명*미      NaN  2015.11.12
# 7008    986410      이*규      NaN  2015.11.12
# 7009    981495      박*선      NaN  2015.11.11
# 7010    972599      이*대      NaN  2015.11.10
# 7011    972574      이*주      NaN  2015.11.10
# 7012    971510      김*리      NaN  2015.11.10
# 7013    970169      오*경      NaN  2015.11.09
# 7014    969965      김*희      NaN  2015.11.09
# 7015    958519      오*경      NaN  2015.11.08
# 7016    958285      박*진      NaN  2015.11.08
# 7017    955039      그린벨      NaN  2015.11.07
# 7018    944449      정*미      NaN  2015.11.05
# 7019    916315      김*희      NaN  2015.11.01
# 7020    916184      박*선      NaN  2015.11.01
# 7021    875538      김*진      NaN  2015.10.24
# 7022    859519      목*균      NaN  2015.10.21
# 7023    765117      정*정      NaN  2015.10.05
# 7024    746711      장*순      NaN  2015.10.02
#
#                                                    text  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# 5                                                   NaN
# 6                                                   NaN
# 7                                                   NaN
# 8     \n                    \n                      ...
# 9     \n                    \n                      ...
# 10                                                  NaN
# 11                                                  NaN
# 12                                                  NaN
# 13    \n                    \n                      ...
# 14    \n                    \n                      ...
# 15    \n                    \n                      ...
# 16    \n                    \n                      ...
# 17                                                  NaN
# 18                                                  NaN
# 19                                                  NaN
# 20                                                  NaN
# 21                                                  NaN
# 22                                                  NaN
# 23    \n                    \n                      ...
# 24                                                  NaN
# 25                                                  NaN
# 26                                                  NaN
# 27                                                  NaN
# 28                                                  NaN
# 29                                                  NaN
# ...                                                 ...
# 6995  \n                    \n                      ...
# 6996  \n                    \n                      ...
# 6997  \n                    \n                      ...
# 6998  \n                    \n                      ...
# 6999  \n                    \n                      ...
# 7000  \n                    \n                      ...
# 7001  \n                    \n                      ...
# 7002  \n                    \n                      ...
# 7003  \n                    \n                      ...
# 7004  \n                    \n                      ...
# 7005  \n                    \n                      ...
# 7006  \n                    \n                      ...
# 7007  \n                    \n                      ...
# 7008  \n                    \n                      ...
# 7009  \n                    \n                      ...
# 7010  \n                    \n                      ...
# 7011  \n                    \n                      ...
# 7012  \n                    \n                      ...
# 7013  \n                    \n                      ...
# 7014  \n                    \n                      ...
# 7015  \n                    \n                      ...
# 7016  \n                    \n                      ...
# 7017  \n                    \n                      ...
# 7018  \n                    \n                      ...
# 7019  \n                    \n                      ...
# 7020  \n                    \n                      ...
# 7021  \n                    \n                      ...
# 7022  \n                    \n                      ...
# 7023  \n                    \n                      ...
# 7024  \n                    \n                      ...
#
#                               option_name  help_count   perfume  moisture
# 0        피지오겔  데일리 모이스쳐 테라피 페이셜 크림, 150ml           0   아주 만족해요       NaN
# 1         피지오겔 데일리 모이스쳐 테라피 페이셜 크림, 150ml           0       NaN       NaN
# 2         피지오겔 데일리 모이스쳐 테라피 페이셜 크림, 150ml           0   아주 만족해요  예상만큼 좋아요
# 3        피지오겔  데일리 모이스쳐 테라피 페이셜 크림, 150ml           0       NaN       NaN
# 4         피지오겔 데일리 모이스쳐 테라피 페이셜 크림, 150ml           0       NaN       NaN
# 5         피지오겔 데일리 모이스쳐 테라피 페이셜 크림, 150ml           0       NaN       NaN
# 6                    [피지오겔] DMT 크림  150ml           0       NaN       NaN
# 7        피지오겔 데일리 모이스쳐 테라피 페이셜 크림 , 150ml           0       NaN       NaN
# 8         피지오겔 데일리 모이스쳐 테라피 페이셜 크림, 150ml           0   아주 만족해요  예상만큼 좋아요
# 9         피지오겔 데일리 모이스쳐 테라피 페이셜 크림, 150ml           0   아주 만족해요  예상만큼 좋아요
# 10        피지오겔 데일리 모이스쳐 테라피 페이셜 크림, 150ml           0       NaN       NaN
# 11        피지오겔 데일리 모이스쳐 테라피 페이셜 크림, 150ml           0       NaN       NaN
# 12        피지오겔 데일리 모이스쳐 테라피 페이셜 크림, 150ml           0   아주 만족해요       NaN
# 13        피지오겔 데일리 모이스쳐 테라피 페이셜 크림, 150ml           0       NaN       NaN
# 14        피지오겔 데일리 모이스쳐 테라피 페이셜 크림, 150ml           0   아주 만족해요  예상만큼 좋아요
# 15        피지오겔 데일리 모이스쳐 테라피 페이셜 크림, 150ml           0       NaN       NaN
# 16        피지오겔 데일리 모이스쳐 테라피 페이셜 크림, 150ml           0   아주 만족해요  예상만큼 좋아요
# 17        피지오겔 데일리 모이스쳐 테라피 페이셜 크림, 150ml           0       NaN       NaN
# 18        피지오겔 데일리 모이스쳐 테라피 페이셜 크림, 150ml           0   아주 만족해요  예상만큼 좋아요
# 19        피지오겔 데일리 모이스쳐 테라피 페이셜 크림, 150ml           0       NaN       NaN
# 20        피지오겔 데일리 모이스쳐 테라피 페이셜 크림, 150ml           0       NaN       NaN
# 21                   [피지오겔] DMT 크림  150ml           0       NaN       NaN
# 22                   [피지오겔] DMT 크림  150ml           0       NaN       NaN
# 23        피지오겔 데일리 모이스쳐 테라피 페이셜 크림, 150ml           0   아주 만족해요  예상만큼 좋아요
# 24        피지오겔 데일리 모이스쳐 테라피 페이셜 크림, 150ml           0  적당히 만족해요   중간 정도에요
# 25    피지오겔 데일리 모이스쳐 테라피 페이셜 크림, 150ml, 2개           0       NaN       NaN
# 26        피지오겔 데일리 모이스쳐 테라피 페이셜 크림, 150ml           0       NaN       NaN
# 27       피지오겔 데일리 모이스쳐 테라피 페이셜 크림 , 150ml           0       NaN       NaN
# 28         피지오겔 데일리모이스쳐 테라피 페이셜 크림, 150ml           0       NaN       NaN
# 29        피지오겔 데일리 모이스쳐 테라피 페이셜 크림, 150ml           0   아주 만족해요  예상만큼 좋아요
# ...                                   ...         ...       ...       ...
# 6995                 [피지오겔] DMT 크림  150ml           6       NaN       NaN
# 6996                 [피지오겔] DMT 크림  150ml           0       NaN       NaN
# 6997                 피지오겔 DMT 크림\n  150ml           0       NaN       NaN
# 6998                 [피지오겔] DMT 크림  150ml           1       NaN       NaN
# 6999                 [피지오겔] DMT 크림  150ml           0       NaN       NaN
# 7000                 피지오겔 DMT 크림\n  150ml           0       NaN       NaN
# 7001                 [피지오겔] DMT 크림  150ml           2       NaN       NaN
# 7002                 [피지오겔] DMT 크림  150ml           0       NaN       NaN
# 7003                 피지오겔 DMT 크림\n  150ml           1       NaN       NaN
# 7004                 [피지오겔] DMT 크림  150ml           0       NaN       NaN
# 7005                 [피지오겔] DMT 크림  150ml           0       NaN       NaN
# 7006                 [피지오겔] DMT 크림  150ml           9       NaN       NaN
# 7007                 피지오겔 DMT 크림\n  150ml           0       NaN       NaN
# 7008                 [피지오겔] DMT 크림  150ml           1       NaN       NaN
# 7009                 [피지오겔] DMT 크림  150ml           0       NaN       NaN
# 7010                 피지오겔 DMT 크림\n  150ml           3       NaN       NaN
# 7011                 피지오겔 DMT 크림\n  150ml           0       NaN       NaN
# 7012                 피지오겔 DMT 크림\n  150ml           0       NaN       NaN
# 7013                 피지오겔 DMT 크림\n  150ml           0       NaN       NaN
# 7014                 피지오겔 DMT 크림\n  150ml           0       NaN       NaN
# 7015                 피지오겔 DMT 크림\n  150ml           2       NaN       NaN
# 7016                 피지오겔 DMT 크림\n  150ml           2       NaN       NaN
# 7017                 피지오겔 DMT 크림\n  150ml           1       NaN       NaN
# 7018                 피지오겔 DMT 크림\n  150ml           0       NaN       NaN
# 7019                 피지오겔 DMT 크림\n  150ml           0       NaN       NaN
# 7020                 피지오겔 DMT 크림\n  150ml           6       NaN       NaN
# 7021                 피지오겔 DMT 크림\n  150ml           0       NaN       NaN
# 7022                 피지오겔 DMT 크림\n  150ml           2       NaN       NaN
# 7023                 피지오겔 DMT 크림\n  150ml           0       NaN       NaN
# 7024                 피지오겔 DMT 크림\n  150ml          12       NaN       NaN
#
# [7025 rows x 9 columns]

# %%
df.loc[df.text == None]
# Out:
# Empty DataFrame
# Columns: [uid, user_name, rating, date, text, option_name, help_count, perfume, moisture]
# Index: []

# %%
df.text[0]
# Out:
# nan

# %%
df.dropna(subset=['text'])
# Out:
#            uid user_name  rating        date  \
# 8     28618460      정*지      NaN  2017.08.05
# 9     28608506      강*진      NaN  2017.08.05
# 13    28584972      정*훈      NaN  2017.08.05
# 14    28584914      조*라      NaN  2017.08.05
# 15    28581673      안*영      NaN  2017.08.04
# 16    28567308      윤*나      NaN  2017.08.04
# 23    28542147      김*희      NaN  2017.08.04
# 31    28465156      최*희      NaN  2017.08.03
# 32    28463679      나랑맘      NaN  2017.08.03
# 34    28454963      한*희      NaN  2017.08.02
# 37    28418125      박*구      NaN  2017.08.02
# 40    28397315      전*은      NaN  2017.08.02
# 43    28371541      김*탁      NaN  2017.08.01
# 46    28359911      김*완      NaN  2017.08.01
# 49    28337356      장*준      NaN  2017.08.01
# 51    28329552      김*영      NaN  2017.07.31
# 52    28323871   Maylyn      NaN  2017.07.31
# 54    28322750      심*호      NaN  2017.07.31
# 55    28320663      오*정      NaN  2017.07.31
# 59    28291046      박*석      NaN  2017.07.31
# 62    28256210      유*현      NaN  2017.07.30
# 63    28249981      정*진      NaN  2017.07.30
# 64    28246576      박*혁      NaN  2017.07.30
# 65    28234198      안*현      NaN  2017.07.30
# 66    28233222      김*현      NaN  2017.07.30
# 72    28202482      현*주      NaN  2017.07.29
# 73    28200055     엄마엄마      NaN  2017.07.29
# 76    28188410      배*희      NaN  2017.07.29
# 83    28115326      안*설      NaN  2017.07.28
# 89    28079136      홍*영      NaN  2017.07.27
# ...        ...       ...     ...         ...
# 6995   1057747      이*미      NaN  2015.11.24
# 6996   1055044      박*석      NaN  2015.11.24
# 6997   1036945      배*채      NaN  2015.11.20
# 6998   1034835      원*빈      NaN  2015.11.20
# 6999   1031622      김*정      NaN  2015.11.19
# 7000   1030423      김*희      NaN  2015.11.19
# 7001   1026544      장*현      NaN  2015.11.18
# 7002   1025879      채*은      NaN  2015.11.18
# 7003   1023053      김*선      NaN  2015.11.18
# 7004    999123      한*숙      NaN  2015.11.14
# 7005    999036      최*아      NaN  2015.11.14
# 7006    998151      전*주      NaN  2015.11.13
# 7007    990590      명*미      NaN  2015.11.12
# 7008    986410      이*규      NaN  2015.11.12
# 7009    981495      박*선      NaN  2015.11.11
# 7010    972599      이*대      NaN  2015.11.10
# 7011    972574      이*주      NaN  2015.11.10
# 7012    971510      김*리      NaN  2015.11.10
# 7013    970169      오*경      NaN  2015.11.09
# 7014    969965      김*희      NaN  2015.11.09
# 7015    958519      오*경      NaN  2015.11.08
# 7016    958285      박*진      NaN  2015.11.08
# 7017    955039      그린벨      NaN  2015.11.07
# 7018    944449      정*미      NaN  2015.11.05
# 7019    916315      김*희      NaN  2015.11.01
# 7020    916184      박*선      NaN  2015.11.01
# 7021    875538      김*진      NaN  2015.10.24
# 7022    859519      목*균      NaN  2015.10.21
# 7023    765117      정*정      NaN  2015.10.05
# 7024    746711      장*순      NaN  2015.10.02
#
#                                                    text  \
# 8     \n                    \n                      ...
# 9     \n                    \n                      ...
# 13    \n                    \n                      ...
# 14    \n                    \n                      ...
# 15    \n                    \n                      ...
# 16    \n                    \n                      ...
# 23    \n                    \n                      ...
# 31    \n                    \n                      ...
# 32    \n                    \n                      ...
# 34    \n                    \n                      ...
# 37    \n                    \n                      ...
# 40    \n                    \n                      ...
# 43    \n                    \n                      ...
# 46    \n                    \n                      ...
# 49    \n                    \n                      ...
# 51    \n                    \n                      ...
# 52    \n                    \n                      ...
# 54    \n                    \n                      ...
# 55    \n                    \n                      ...
# 59    \n                    \n                      ...
# 62    \n                    \n                      ...
# 63    \n                    \n                      ...
# 64    \n                    \n                      ...
# 65    \n                    \n                      ...
# 66    \n                    \n                      ...
# 72    \n                    \n                      ...
# 73    \n                    \n                      ...
# 76    \n                    \n                      ...
# 83    \n                    \n                      ...
# 89    \n                    \n                      ...
# ...                                                 ...
# 6995  \n                    \n                      ...
# 6996  \n                    \n                      ...
# 6997  \n                    \n                      ...
# 6998  \n                    \n                      ...
# 6999  \n                    \n                      ...
# 7000  \n                    \n                      ...
# 7001  \n                    \n                      ...
# 7002  \n                    \n                      ...
# 7003  \n                    \n                      ...
# 7004  \n                    \n                      ...
# 7005  \n                    \n                      ...
# 7006  \n                    \n                      ...
# 7007  \n                    \n                      ...
# 7008  \n                    \n                      ...
# 7009  \n                    \n                      ...
# 7010  \n                    \n                      ...
# 7011  \n                    \n                      ...
# 7012  \n                    \n                      ...
# 7013  \n                    \n                      ...
# 7014  \n                    \n                      ...
# 7015  \n                    \n                      ...
# 7016  \n                    \n                      ...
# 7017  \n                    \n                      ...
# 7018  \n                    \n                      ...
# 7019  \n                    \n                      ...
# 7020  \n                    \n                      ...
# 7021  \n                    \n                      ...
# 7022  \n                    \n                      ...
# 7023  \n                    \n                      ...
# 7024  \n                    \n                      ...
#
#                               option_name  help_count   perfume  moisture
# 8         피지오겔 데일리 모이스쳐 테라피 페이셜 크림, 150ml           0   아주 만족해요  예상만큼 좋아요
# 9         피지오겔 데일리 모이스쳐 테라피 페이셜 크림, 150ml           0   아주 만족해요  예상만큼 좋아요
# 13        피지오겔 데일리 모이스쳐 테라피 페이셜 크림, 150ml           0       NaN       NaN
# 14        피지오겔 데일리 모이스쳐 테라피 페이셜 크림, 150ml           0   아주 만족해요  예상만큼 좋아요
# 15        피지오겔 데일리 모이스쳐 테라피 페이셜 크림, 150ml           0       NaN       NaN
# 16        피지오겔 데일리 모이스쳐 테라피 페이셜 크림, 150ml           0   아주 만족해요  예상만큼 좋아요
# 23        피지오겔 데일리 모이스쳐 테라피 페이셜 크림, 150ml           0   아주 만족해요  예상만큼 좋아요
# 31        피지오겔 데일리 모이스쳐 테라피 페이셜 크림, 150ml           0       NaN       NaN
# 32        피지오겔 데일리 모이스쳐 테라피 페이셜 크림, 150ml           0       NaN       NaN
# 34        피지오겔 데일리 모이스쳐 테라피 페이셜 크림, 150ml           0   아주 만족해요       NaN
# 37        피지오겔 데일리 모이스쳐 테라피 페이셜 크림, 150ml           0  적당히 만족해요       NaN
# 40        피지오겔 데일리 모이스쳐 테라피 페이셜 크림, 150ml           1   아주 만족해요  예상만큼 좋아요
# 43        피지오겔 데일리 모이스쳐 테라피 페이셜 크림, 150ml           0  적당히 만족해요  예상만큼 좋아요
# 46        피지오겔 데일리 모이스쳐 테라피 페이셜 크림, 150ml           0  적당히 만족해요       NaN
# 49        피지오겔 데일리 모이스쳐 테라피 페이셜 크림, 150ml           0       NaN       NaN
# 51        피지오겔 데일리 모이스쳐 테라피 페이셜 크림, 150ml           0       NaN       NaN
# 52        피지오겔 데일리 모이스쳐 테라피 페이셜 크림, 150ml           0  적당히 만족해요  예상만큼 좋아요
# 54        피지오겔 데일리 모이스쳐 테라피 페이셜 크림, 150ml           0       NaN       NaN
# 55    피지오겔 데일리 모이스쳐 테라피 페이셜 크림, 150ml, 2개           0   아주 만족해요       NaN
# 59        피지오겔 데일리 모이스쳐 테라피 페이셜 크림, 150ml           0   아주 만족해요  예상만큼 좋아요
# 62        피지오겔 데일리 모이스쳐 테라피 페이셜 크림, 150ml           0       NaN       NaN
# 63        피지오겔 데일리 모이스쳐 테라피 페이셜 크림, 150ml           0       NaN       NaN
# 64       피지오겔 데일리 모이스쳐 테라피 페이셜 크림 , 150ml           0       NaN       NaN
# 65        피지오겔 데일리 모이스쳐 테라피 페이셜 크림, 150ml           0       NaN       NaN
# 66        피지오겔 데일리 모이스쳐 테라피 페이셜 크림, 150ml           0       NaN       NaN
# 72        피지오겔 데일리 모이스쳐 테라피 페이셜 크림, 150ml           0       NaN       NaN
# 73        피지오겔 데일리 모이스쳐 테라피 페이셜 크림, 150ml           0       NaN       NaN
# 76        피지오겔 데일리 모이스쳐 테라피 페이셜 크림, 150ml           0   아주 만족해요  예상만큼 좋아요
# 83       피지오겔  데일리 모이스쳐 테라피 페이셜 크림, 150ml           0   아주 만족해요  예상만큼 좋아요
# 89        피지오겔 데일리 모이스쳐 테라피 페이셜 크림, 150ml           0   아주 만족해요       NaN
# ...                                   ...         ...       ...       ...
# 6995                 [피지오겔] DMT 크림  150ml           6       NaN       NaN
# 6996                 [피지오겔] DMT 크림  150ml           0       NaN       NaN
# 6997                 피지오겔 DMT 크림\n  150ml           0       NaN       NaN
# 6998                 [피지오겔] DMT 크림  150ml           1       NaN       NaN
# 6999                 [피지오겔] DMT 크림  150ml           0       NaN       NaN
# 7000                 피지오겔 DMT 크림\n  150ml           0       NaN       NaN
# 7001                 [피지오겔] DMT 크림  150ml           2       NaN       NaN
# 7002                 [피지오겔] DMT 크림  150ml           0       NaN       NaN
# 7003                 피지오겔 DMT 크림\n  150ml           1       NaN       NaN
# 7004                 [피지오겔] DMT 크림  150ml           0       NaN       NaN
# 7005                 [피지오겔] DMT 크림  150ml           0       NaN       NaN
# 7006                 [피지오겔] DMT 크림  150ml           9       NaN       NaN
# 7007                 피지오겔 DMT 크림\n  150ml           0       NaN       NaN
# 7008                 [피지오겔] DMT 크림  150ml           1       NaN       NaN
# 7009                 [피지오겔] DMT 크림  150ml           0       NaN       NaN
# 7010                 피지오겔 DMT 크림\n  150ml           3       NaN       NaN
# 7011                 피지오겔 DMT 크림\n  150ml           0       NaN       NaN
# 7012                 피지오겔 DMT 크림\n  150ml           0       NaN       NaN
# 7013                 피지오겔 DMT 크림\n  150ml           0       NaN       NaN
# 7014                 피지오겔 DMT 크림\n  150ml           0       NaN       NaN
# 7015                 피지오겔 DMT 크림\n  150ml           2       NaN       NaN
# 7016                 피지오겔 DMT 크림\n  150ml           2       NaN       NaN
# 7017                 피지오겔 DMT 크림\n  150ml           1       NaN       NaN
# 7018                 피지오겔 DMT 크림\n  150ml           0       NaN       NaN
# 7019                 피지오겔 DMT 크림\n  150ml           0       NaN       NaN
# 7020                 피지오겔 DMT 크림\n  150ml           6       NaN       NaN
# 7021                 피지오겔 DMT 크림\n  150ml           0       NaN       NaN
# 7022                 피지오겔 DMT 크림\n  150ml           2       NaN       NaN
# 7023                 피지오겔 DMT 크림\n  150ml           0       NaN       NaN
# 7024                 피지오겔 DMT 크림\n  150ml          12       NaN       NaN
#
# [3072 rows x 9 columns]

# %%
df = df[np.isfinite(df['EPS'])]
